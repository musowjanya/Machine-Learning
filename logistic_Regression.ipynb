# %% [markdown]
# <a href="https://colab.research.google.com/github/musowjanya/ML_Mini_Projects/blob/main/logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_moons

# %%
X,Y=make_moons(n_samples=1000,noise=0.15, random_state=0)

# %%
X.shape,Y.shape
# Out:
# ((1000, 2), (1000,))

# %%
# !pip install mglearn --q

# %%
import mglearn as mg

# %%
mg.discrete_scatter(X[:,0],X[:,1],Y)

# %%
from sklearn.neural_network import MLPClassifier

# %%
model=MLPClassifier((1000,200))

# %%
model.fit(X,Y)
# Out:
# MLPClassifier(hidden_layer_sizes=(1000, 200))

# %%
yp=model.predict(X)

# %%
mg.discrete_scatter(X[:,0],X[:,1],Y)
mg.plots.plot_2d_separator(model,X)
